# %%
# Importing the Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
# Importing the Dataset
df = pd.read_csv("D:/VIT/Externship - SmartBridge/Titanic-Dataset.csv")

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Checking for Null Values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Data Visualization

plt.figure(figsize=(8, 6))
sns.histplot(df['Age'].dropna(), bins=30, kde=True)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.show()

# %%
import matplotlib.pyplot as plt

# Example: Creating a scatter plot for Age vs. Fare
plt.figure(figsize=(8, 6))
plt.scatter(df['Age'], df['Fare'], alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot: Age vs. Fare')
plt.show()

# %%
import matplotlib.pyplot as plt

# Example: Creating a bar chart for Passenger Class counts
class_counts = df['Pclass'].value_counts()
plt.figure(figsize=(8, 6))
plt.bar(class_counts.index, class_counts.values)
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.title('Passenger Class Counts')
plt.show()

# %%
import seaborn as sns

# Example: Creating a heatmap for feature correlations
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_1796\563815132.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
import seaborn as sns

# Example: Creating a pair plot for selected features
sns.pairplot(df[['Age', 'Fare', 'Pclass', 'Survived']], hue='Survived')
plt.title('Pair Plot of Age, Fare, Pclass, and Survival')
plt.show()

# %%
# Outlier Detection
# Example: Visualizing outliers using a boxplot for Fare
plt.figure(figsize=(8, 6))
sns.boxplot(x='Fare', data=df)
plt.xlabel('Fare')
plt.title('Fare Outliers')
plt.show()

# %%
import seaborn as sns

# Example: Creating a box plot for Fare
plt.figure(figsize=(8, 6))
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.title('Fare Distribution by Passenger Class')
plt.show()

# %%
# Checking for Null Values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())

# %%
df.drop('Cabin',axis=1, inplace=True)

# %%
df["Embarked"]=df["Embarked"].fillna(df["Embarked"].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
sns.boxplot(df.Age)
# Out:
# <Axes: >

# %%
q1 = df.Age.quantile(0.25)
q3 = df.Age.quantile(0.75)
print(q1,q3)
# Out:
# 22.0 35.0

# %%
IQR = q3-q1
IQR
# Out:
# 13.0

# %%
upper_limit = q3+1.5*IQR
upper_limit
# Out:
# 54.5

# %%
lower_limit = q1-1.5*IQR
lower_limit
# Out:
# 2.5

# %%
df = df[df.Age<54.5]

# %%
sns.boxplot(df.Age)
# Out:
# <Axes: >

# %%
# Splitting Dependent and Independent Variables
X = df.drop('Survived', axis=1)
y = df['Survived']

# %%
X
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 849, dtype: int64

# %%
X.shape
# Out:
# (849, 10)

# %%
y.shape
# Out:
# (849,)

# %%
# Perform Encoding
X_encoded = pd.get_dummies(X, columns=['Embarked'], drop_first=True)
X_encoded
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
X["Sex"]=le.fit_transform(X["Sex"])
X["Sex"]
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: Sex, Length: 849, dtype: int32

# %%
X["Sex"].value_counts()
# Out:
# 1    545
# 0    304
# Name: Sex, dtype: int64

# %%
# Feature Scaling
numeric_columns = X_encoded.select_dtypes(include=['number']).columns

scaler = StandardScaler()
X_scaled = X_encoded.copy()  # Create a copy of the encoded DataFrame

# Scale only the numerical columns
X_scaled[numeric_columns] = scaler.fit_transform(X_encoded[numeric_columns])
X_scaled[numeric_columns]
# Out:
#      PassengerId    Pclass       Age     SibSp     Parch      Fare  \
# 0      -1.731434  0.796030 -0.553565  0.407989 -0.477709 -0.490724
# 1      -1.727550 -1.643787  0.898124  0.407989 -0.477709  0.800246
# 2      -1.723667  0.796030 -0.190642 -0.482455 -0.477709 -0.477115
# 3      -1.719783 -1.643787  0.625932  0.407989 -0.477709  0.433654
# 4      -1.715899  0.796030  0.625932 -0.482455 -0.477709 -0.474595
# ..           ...       ...       ...       ...       ...       ...
# 886     1.709541 -0.423879 -0.099912 -0.482455 -0.477709 -0.374799
# 887     1.713424 -1.643787 -0.825756 -0.482455 -0.477709 -0.032063
# 888     1.717308  0.796030  0.144980  0.407989  1.995309 -0.164117
# 889     1.721192 -1.643787 -0.190642 -0.482455 -0.477709 -0.032063
# 890     1.725076  0.796030  0.353741 -0.482455 -0.477709 -0.480644
#
#      Embarked_Q  Embarked_S
# 0     -0.309005    0.611381
# 1     -0.309005   -1.635642
# 2     -0.309005    0.611381
# 3     -0.309005    0.611381
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((679, 11), (170, 11), (679,), (170,))
